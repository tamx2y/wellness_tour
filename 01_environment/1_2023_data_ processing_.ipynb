# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2023년 데이터 전처리

# %%
df= pd.read_excel('data/2023/2023 외래관광객조사 DATA.xlsx')

print(df.head())
# Out:
#    pnid  MVIT  RVIT  XRVIT  TYP  Q1  Q1_1a1  Q1_1a2  Q1_1a3  Q2a1  ...  Q14  \
# 0     6     4     4    5.0    1   1     2.0     3.0     4.0   4.0  ...    5
# 1     7    20     4    5.0    1   2     2.0     9.0     7.0   NaN  ...    5
# 2     8     2     2    5.0    1   5     NaN     NaN     NaN   NaN  ...    5
# 3    10     1     1    NaN    1   3     NaN     NaN     NaN   NaN  ...    4
# 4    11     3     3    5.0    1   2     8.0     3.0     7.0   NaN  ...    5
#
#    D_MON  D_BUN  D_NAT  D_SEX  D_AGE  D_MOK  D_NUM  D_GUB      weight
# 0      1      1      3      2      2      1      4      1  866.099893
# 1      1      1      1      1      3      2      4      1  191.333757
# 2      1      1      4      2      1      5      2      1  244.838755
# 3      1      1      5      1      5      3      1      1  555.272342
# 4      1      1      1      2      4      2      3      1  193.434506
#
# [5 rows x 365 columns]

# %% [markdown]
# - 국적: D_NAT
# - 체류기간: M일HAP
# - 동반자 유무: Q7A
# - 동행자 유형: Q7a_dk ~ Q7a8
# - 여행 형태: D_GUB
# - 방문 목적: D_MOK
# - 총지출: 총액1인TOT2
# - 여가·체험 관련 지출 항목: C문화서1인대체, C오락및1인대체, C미용서1인대체
# - 가중치: weight

# %%
cols_needed = ['D_NAT', 'M일HAP', 
               'Q7A','Q7a_dk', 'Q7a2', 'Q7a3', 'Q7a4', 'Q7a5', 'Q7a6', 'Q7a7', 'Q7a8',
               'D_GUB', 'D_MOK', '총액1인TOT2', 
               'C문화서1인대체', 'C오락및1인대체', 'C미용서1인대체', 'weight']
df = df[cols_needed]

# %%
df
# Out:
#        D_NAT  M일HAP  Q7A  Q7a_dk  Q7a2  Q7a3  Q7a4  Q7a5  Q7a6  Q7a7  Q7a8  \
# 0          3     27    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          1      7    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          4      2    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          5      8    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          1     71    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...    ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 16191      1      6    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16192      1      5    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16193      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16194      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16195      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
#
#        D_GUB  D_MOK    총액1인TOT2  C문화서1인대체  C오락및1인대체  C미용서1인대체       weight
# 0          1      1  1633.63664         2         1         1   866.099893
# 1          1      2  2007.30400         1         1         1   191.333757
# 2          1      5  1650.00000         1         1         1   244.838755
# 3          1      3  3586.80000         1         1         1   555.272342
# 4          1      2  2151.56000         1         1         1   193.434506
# ...      ...    ...         ...       ...       ...       ...          ...
# 16191      1      1  1178.52000         1         1         1  1205.023267
# 16192      1      1  5092.89000         1         1         1  1160.261837
# 16193      1      2   525.82588         2         1         1  1403.603404
# 16194      1      1   498.06500         1         1         1  1220.901706
# 16195      1      1   505.08000         1         1         1  2148.789345
#
# [16196 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# D_NAT           0
# M일HAP           0
# Q7A             0
# Q7a_dk      10690
# Q7a2        13369
# Q7a3        14923
# Q7a4        14887
# Q7a5        14512
# Q7a6        12350
# Q7a7        14476
# Q7a8        16078
# D_GUB           0
# D_MOK           0
# 총액1인TOT2        0
# C문화서1인대체        0
# C오락및1인대체        0
# C미용서1인대체        0
# weight          0
# dtype: int64

# %% [markdown]
# ### 동행자 유형 분류

# %%
# 1. 동행자 관련 컬럼만 추출
companion_cols = ['Q7a_dk', 'Q7a2', 'Q7a3', 'Q7a4', 'Q7a5', 'Q7a6', 'Q7a7', 'Q7a8']

# 2. 결측치 처리 안함 
# 결측치는 <선택하지 않음>을 의미하므로 처리하지 않음

# 3. 동행자유형 파생 변수 만들기
def classify_companion(row):
    # 혼자 온 경우
    if row['Q7a_dk'] == 1:
        return '혼자'

    # 가족 유형
    if any([
        row['Q7a2'] == 2,
        row['Q7a3'] == 3,
        row['Q7a4'] == 4,
        row['Q7a5'] == 5
    ]):
        return '가족'

    # 친구
    if row['Q7a6'] == 6:
        return '친구'

    # 직장동료
    if row['Q7a7'] == 7:
        return '직장동료'

    # 기타
    if row['Q7a8'] == 8:
        return '기타'

    # 아무 것도 선택하지 않은 경우
    return '응답없음'

# 4. 적용
df['동행자유형'] = df.apply(classify_companion, axis=1)

# 5. 유효 응답만 남기기
df = df[df['동행자유형'] != '응답없음'].copy()

# %%
df.isnull().sum()
# Out:
# D_NAT           0
# M일HAP           0
# Q7A             0
# Q7a_dk      10690
# Q7a2        13369
# Q7a3        14923
# Q7a4        14887
# Q7a5        14512
# Q7a6        12350
# Q7a7        14476
# Q7a8        16078
# D_GUB           0
# D_MOK           0
# 총액1인TOT2        0
# C문화서1인대체        0
# C오락및1인대체        0
# C미용서1인대체        0
# weight          0
# 동행자유형           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['D_NAT', 'M일HAP', 'Q7A', 'Q7a_dk', 'Q7a2', 'Q7a3', 'Q7a4', 'Q7a5',
#        'Q7a6', 'Q7a7', 'Q7a8', 'D_GUB', 'D_MOK', '총액1인TOT2', 'C문화서1인대체',
#        'C오락및1인대체', 'C미용서1인대체', 'weight', '동행자유형'],
#       dtype='object')

# %%
df['동행자유형'].value_counts()
# Out:
# 동행자유형
# 가족      5511
# 혼자      5506
# 친구      3526
# 직장동료    1588
# 기타        65
# Name: count, dtype: int64

# %% [markdown]
# ### 국적 선별
# - 2023년 글로벌 방한 관광객 통계 기준 상위 6개국
# - GWI-Rankings 상위 5개국 중 2개국(방한관광객 상위 국가와 중복 제외)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
df['D_NAT'].value_counts()
# Out:
# D_NAT
# 2     1963
# 1     1588
# 4     1444
# 3     1263
# 10     873
# 5      868
# 6      824
# 97     682
# 8      678
# 13     664
# 15     639
# 12     583
# 14     537
# 7      521
# 9      512
# 19     497
# 18     496
# 16     488
# 20     385
# 17     359
# 11     332
# Name: count, dtype: int64

# %% [markdown]
# ### 국가명 매핑

# %%
df['D_NAT'].dtype
# Out:
# dtype('int64')

# %%
nat_map = {
    1: '중국',
    2: '일본',
    3: '대만',
    4: '미국',
    5: '홍콩',
    6: '태국',
    7: '베트남',
    10: '싱가포르',
    16: '영국',
    18: '독일'
}

df['국가명'] = df['D_NAT'].map(nat_map)

# 분석 대상 국가만 필터링
df = df[df['국가명'].notna()]

# %%
df
# Out:
#        D_NAT  M일HAP  Q7A  Q7a_dk  Q7a2  Q7a3  Q7a4  Q7a5  Q7a6  Q7a7  Q7a8  \
# 0          3     27    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          1      7    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          4      2    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          5      8    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          1     71    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...    ...  ...     ...   ...   ...   ...   ...   ...   ...   ...
# 16191      1      6    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16192      1      5    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16193      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16194      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
# 16195      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN   NaN
#
#        D_GUB  D_MOK    총액1인TOT2  C문화서1인대체  C오락및1인대체  C미용서1인대체       weight  \
# 0          1      1  1633.63664         2         1         1   866.099893
# 1          1      2  2007.30400         1         1         1   191.333757
# 2          1      5  1650.00000         1         1         1   244.838755
# 3          1      3  3586.80000         1         1         1   555.272342
# 4          1      2  2151.56000         1         1         1   193.434506
# ...      ...    ...         ...       ...       ...       ...          ...
# 16191      1      1  1178.52000         1         1         1  1205.023267
# 16192      1      1  5092.89000         1         1         1  1160.261837
# 16193      1      2   525.82588         2         1         1  1403.603404
# 16194      1      1   498.06500         1         1         1  1220.901706
# 16195      1      1   505.08000         1         1         1  2148.789345
#
#       동행자유형 국가명
# 0        혼자  대만
# 1        혼자  중국
# 2        혼자  미국
# 3        혼자  홍콩
# 4        혼자  중국
# ...     ...  ..
# 16191    친구  중국
# 16192    친구  중국
# 16193    친구  중국
# 16194    친구  중국
# 16195    친구  중국
#
# [10328 rows x 20 columns]

# %%
df['국가명'].value_counts()
# Out:
# 국가명
# 일본      1963
# 중국      1588
# 미국      1444
# 대만      1263
# 싱가포르     873
# 홍콩       868
# 태국       824
# 베트남      521
# 독일       496
# 영국       488
# Name: count, dtype: int64

# %%
df['C문화서1인대체'].isnull().sum()
df['C미용서1인대체'].isnull().sum()
df['C오락및1인대체'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 여가·체험 지출 비율 변수 만들기
# - 여가체험비율 = (C문화서1인대체 + C미용서1인대체 + C오락및1인대체) / 총지출
# - 총액1인TOT2가 0인 경우 → 0으로 나누는 오류 발생 가능 → 제외 필요
# - 결측치는 없지만 분모가 0인 경우를 먼저 제거

# %%
# 총지출이 0 초과인 응답만 필터링
df = df[df['총액1인TOT2'] > 0]

# %%
# 여가체험비율 계산
df['여가체험비율'] = (
    df['C문화서1인대체'] + df['C미용서1인대체'] + df['C오락및1인대체']
) / df['총액1인TOT2']

# %%
df['여가체험비율'].head(15)
# Out:
# 0     0.002449
# 1     0.001495
# 2     0.001818
# 3     0.000836
# 4     0.001394
# 5     0.001964
# 7     0.000968
# 9     0.001416
# 10    0.003185
# 11    0.001587
# 12    0.002220
# 13    0.003768
# 14    0.002217
# 17    0.001362
# 18    0.001378
# Name: 여가체험비율, dtype: float64

# %%
df['여가체험비율'] = df['여가체험비율'] * 100

# %% [markdown]
# ### 여행 목적 컬럼 (D_MOK) 전처리
# - 여가/위락/힐링, 친구/친지 방문, 사업/전문 활동, 교육, 기타
# - 여가/힐링을 즐길 의사와 여건이 있었던 응답자만 포함

# %%
df['D_MOK'].dtype
# Out:
# dtype('int64')

# %%
df = df[df['D_MOK'].isin([1, 2])]

# %%
df
# Out:
#        D_NAT  M일HAP  Q7A  Q7a_dk  Q7a2  Q7a3  Q7a4  Q7a5  Q7a6  Q7a7  ...  \
# 0          3     27    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1          1      7    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4          1     71    1     1.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5          5      5    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# 9          3      8    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# ...      ...    ...  ...     ...   ...   ...   ...   ...   ...   ...  ...
# 16191      1      6    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# 16192      1      5    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# 16193      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# 16194      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
# 16195      1      4    2     NaN   NaN   NaN   NaN   NaN   6.0   NaN  ...
#
#        D_GUB  D_MOK    총액1인TOT2  C문화서1인대체  C오락및1인대체  C미용서1인대체       weight  \
# 0          1      1  1633.63664         2         1         1   866.099893
# 1          1      2  2007.30400         1         1         1   191.333757
# 4          1      2  2151.56000         1         1         1   193.434506
# 5          1      1  2036.79000         2         1         1   298.390736
# 9          1      1  2119.00000         1         1         1   636.214288
# ...      ...    ...         ...       ...       ...       ...          ...
# 16191      1      1  1178.52000         1         1         1  1205.023267
# 16192      1      1  5092.89000         1         1         1  1160.261837
# 16193      1      2   525.82588         2         1         1  1403.603404
# 16194      1      1   498.06500         1         1         1  1220.901706
# 16195      1      1   505.08000         1         1         1  2148.789345
#
#        동행자유형 국가명    여가체험비율
# 0         혼자  대만  0.244852
# 1         혼자  중국  0.149454
# 4         혼자  중국  0.139434
# 5         친구  홍콩  0.196387
# 9         친구  대만  0.141576
# ...      ...  ..       ...
# 16191     친구  중국  0.254557
# 16192     친구  중국  0.058906
# 16193     친구  중국  0.760708
# 16194     친구  중국  0.602331
# 16195     친구  중국  0.593965
#
# [8060 rows x 21 columns]

# %% [markdown]
# ### 이상치 확인

# %%
# 총액1인TOT2 (총 지출): 0, 음수, 이상치 확인
# 총지출 0 또는 음수 확인
print("총액1인TOT2가 0 이하인 경우 수:", (df['총액1인TOT2'] <= 0).sum())

# 이상치 탐지용 기초 통계
print(df['총액1인TOT2'].describe())

# boxplot 시각화
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df['총액1인TOT2'])
plt.title("총지출 이상치 확인")
plt.show()
# Out:
# 총액1인TOT2가 0 이하인 경우 수: 0
# count     8060.000000
# mean      1901.630595
# std       1668.711402
# min        325.580000
# 25%        881.130000
# 50%       1380.658500
# 75%       2323.378750
# max      12072.500000
# Name: 총액1인TOT2, dtype: float64
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - 비율 중심 분석이므로 절댓값 이상치는 직접 영향 없음
# - 고지출자는 웰니스 콘텐츠 주요 타겟일 가능성도 있음
# - 응답 수 적은 국가나 유형에서 이상치 제거 시 왜곡 우려

# %% [markdown]
# - ANOVA 검정 안정 확보를 위해 로그 변환 변수 추가

# %%
df['log_총액'] = np.log(df['총액1인TOT2'])

# %%
# 여가체험비율: 0 이하 / 1 이상 값 확인
# 비율이 0 이하이거나 1 이상인 경우 확인
print("여가체험비율 ≤ 0:", (df['여가체험비율'] <= 0).sum())
print("여가체험비율 ≥ 1:", (df['여가체험비율'] >= 1).sum())

# 분포 시각화
sns.boxplot(x=df['여가체험비율'])
plt.title("여가체험비율 이상치 확인")
plt.show()
# Out:
# 여가체험비율 ≤ 0: 0
# 여가체험비율 ≥ 1: 60
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54744 (\N{HANGUL SYLLABLE HEOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - 이상치(1.0 초과)는 일부 존재하지만 현실적으로 가능한 사례일 수 있음
# - 전체 분석에서는 그대로 유지하되, 추후 1 이상인 응답자 수와 특성을 보조적으로 점검

# %%
# 분류 성공 여부 및 결측 확인
# 결측치 확인
print("동행자유형 결측치 수:", df['동행자유형'].isnull().sum())

# 고유값 확인
print("동행자유형 고유값 목록:", df['동행자유형'].dropna().unique())
# Out:
# 동행자유형 결측치 수: 0
# 동행자유형 고유값 목록: ['혼자' '친구' '가족' '직장동료' '기타']
