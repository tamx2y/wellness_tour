# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import gc
import glob

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
df23 = pd.read_csv('/content/drive/MyDrive/데이터톤/데이터/2023.csv',encoding='cp949')
df24 = pd.read_csv('/content/drive/MyDrive/데이터톤/데이터/2024.csv',encoding='utf-8')

# %%
# 연도별 데이터에 'year' 컬럼 추가
df23['year'] = 2023
df24['year'] = 2024

# %%
#2023
# 모든 행/열을 화면에 표시하도록 설정
pd.set_option('display.max_columns', None)

#pd.set_option('display.max_rows', None)

# 출력 시 콘솔에 보여줄 전체 너비를 1000으로 설정 (줄바꿈 방지)
pd.set_option('display.width', 1000)

# 필요한 컬럼만 남기고 나머지 모두 drop
cols_to_keep23 = [
    'pnid', 'RVIT', 'TYP', 'Q1', 'Q3_1a1', 'Q3_1a2', 'Q3_1a3','Q3_2a1',
    'Q3_2a2','Q3_2a3','Q8a01','Q8a02','Q8a03','Q8a04','Q8a05',
    'Q8a06', 'Q8a07', 'Q8a08', 'Q8a09', 'Q8a10', 'Q8a11','Q8a12', 'Q8a13',
    'Q8a14', 'Q8a15', 'Q8a16', 'Q8a17', 'Q8a18', 'Q8a19','Q8_1a1','Q8_1a2',
    'Q8_1a3','Q9_2a01','Q9_2a02','Q9_2a03','Q9_2a04','Q9_2a05','Q9_2a06','Q9_2a07',
    'Q9_2a08','Q9_2a09','Q9_2a10','Q9_2a11','Q9_2a12','Q9_2a13','Q9_2a14','Q9_2a15',
    'Q9_2a16','Q9_2a17','R1일HAP','M일HAP','총액1인TOT2','MDAY전체TOT_RAW61','C총액1인MIS',
    'C총액1인TOT2','RDAY전체','RDAY전체TOT_RAW2','RDAY전체TOT_RAW61','RDAY개별대체','RDAY개별61대체',
    'RDAY개별61항공제외대체','C쇼핑비1인대체','C문화서1인대체','C치료및1인대체','C미용서1인대체','C음식점1인대체',
    'C식음료1인대체','C숙박비1인대체','Q11','Q12a01',
    'Q12a02','Q12a03','Q12a12','Q12a13','Q12a14','Q12a15','Q12a19','Q12a20','Q13','Q14',
    'D_MON', 'D_BUN', 'D_NAT', 'D_SEX',
    'D_AGE', 'D_MOK', 'D_NUM', 'D_GUB',
    'weight', 'year'
]

d23 = df23[cols_to_keep23]
d23.head()
# Out:
#    pnid  RVIT  TYP  Q1  Q3_1a1  Q3_1a2  Q3_1a3  Q3_2a1  Q3_2a2  Q3_2a3  Q8a01  Q8a02  Q8a03  Q8a04  Q8a05  Q8a06  Q8a07  Q8a08  Q8a09  Q8a10  Q8a11  Q8a12  Q8a13  Q8a14  Q8a15  Q8a16  Q8a17  Q8a18  Q8a19  Q8_1a1  Q8_1a2  Q8_1a3  Q9_2a01  Q9_2a02  Q9_2a03  Q9_2a04  Q9_2a05  Q9_2a06  Q9_2a07  Q9_2a08  Q9_2a09  Q9_2a10  Q9_2a11  Q9_2a12  Q9_2a13  Q9_2a14  Q9_2a15  Q9_2a16  Q9_2a17  R1일HAP  M일HAP  총액1인TOT2  MDAY전체TOT_RAW61  C총액1인MIS  C총액1인TOT2  RDAY전체  RDAY전체TOT_RAW2  RDAY전체TOT_RAW61  RDAY개별대체  RDAY개별61대체  RDAY개별61항공제외대체  C쇼핑비1인대체  C문화서1인대체  C치료및1인대체  C미용서1인대체  C음식점1인대체  C식음료1인대체  C숙박비1인대체  Q11  Q12a01  Q12a02  Q12a03  Q12a12  Q12a13  Q12a14  Q12a15  Q12a19  Q12a20  Q13  Q14  D_MON  D_BUN  D_NAT  D_SEX  D_AGE  D_MOK  D_NUM  D_GUB      weight  year
# ...

# %%
# 이름 새로 정의
new_names = {
    'pnid': 'id',
    'RVIT': '방문횟수',
    'TYP': '여행형태',
    'Q1': '방한목적',
    'Q3_1a1': '고려한_관광활동_1',
    'Q3_1a2': '고려한_관광활동_2',
    'Q3_1a3': '고려한_관광활동_3',
    'Q3_2a1': '고려한_인프라_1',
    'Q3_2a2': '고려한_인프라_2',
    'Q3_2a3': '고려한_인프라_3',
    'Q8a01': '참여_식도락관광',
    'Q8a02': '참여_쇼핑',
    'Q8a03': '참여_자연경관감상',
    'Q8a04': '참여_역사유적지방문',
    'Q8a05': '참여_전통문화체험',
    'Q8a06': '참여_박물관전시관관람',
    'Q8a07': '참여_한류스타관련',
    'Q8a08': '참여_공연관람',
    'Q8a09': '참여_지역축제',
    'Q8a10': '참여_유흥',
    'Q8a11': '참여_오락',
    'Q8a12': '참여_뷰티미용관광',
    'Q8a13': '참여_치료건강검진',
    'Q8a14': '참여_스포츠관람',
    'Q8a15': '참여_스포츠레포츠참가',
    'Q8a16': '참여_국제회의',
    'Q8a17': '참여_비즈니스',
    'Q8a18': '참여_연수교육연구',
    'Q8a19': '참여_기타',
    'Q8_1a1': '만족한활동_1',
    'Q8_1a2': '만족한활동_2',
    'Q8_1a3': '만족한활동_3',
    'Q9_2a01': '방문지역_서울',
    'Q9_2a02': '방문지역_경기',
    'Q9_2a03': '방문지역_인천',
    'Q9_2a04': '방문지역_강원',
    'Q9_2a05': '방문지역_대전',
    'Q9_2a06': '방문지역_충북',
    'Q9_2a07': '방문지역_충남',
    'Q9_2a08': '방문지역_세종',
    'Q9_2a09': '방문지역_경북',
    'Q9_2a10': '방문지역_경남',
    'Q9_2a11': '방문지역_대구',
    'Q9_2a12': '방문지역_울산',
    'Q9_2a13': '방문지역_부산',
    'Q9_2a14': '방문지역_광주',
    'Q9_2a15': '방문지역_전북',
    'Q9_2a16': '방문지역_전남',
    'Q9_2a17': '방문지역_제주',
    'R1일HAP': '총체재기간(코드형)',
    'M일HAP': '총체재기간',
    '총액1인TOT2': '1인지출경비',
    'MDAY전체TOT_RAW61': '1인1일지출경비',
    'C총액1인MIS': '1인지출경비_영향치결측',
    'C총액1인TOT2': '1인지출경비_상하위1%대체',
    'RDAY전체': '1인1일지출경비_영향치_61일이상결측',
    'RDAY전체TOT_RAW2': '1인1일지출경비_상하위1%대체',
    'RDAY전체TOT_RAW61': '1인1일지출경비_상하위1%대체_61일이상결측',
    'RDAY개별대체': '형태별_1일지출경비',
    'RDAY개별61대체': '형태별_1일지출경비_상하위1%대체_61일이상결측',
    'RDAY개별61항공제외대체': '형태별_1일지출경비_항공제외대체결측',
    'C쇼핑비1인대체': '항목별지출경비_쇼핑',
    'C치료및1인대체': '항목별지출경비_치료',
    'C미용서1인대체': '항목별지출경비_미용',
    'C음식점1인대체': '항목별지출경비_음식점',
    'C식음료1인대체': '항목별지출경비_식음료',
    'C숙박비1인대체': '항목별지출경비숙박비',
    'C문화서1인대체': '항목별지출경비_문화서비스',
    'Q11': '전반적만족도',
    'Q12a01': '항목별만족도_식도락',
    'Q12a02': '항목별만족도_쇼핑',
    'Q12a03': '항목별만족도_자연경관감상',
    'Q12a12': '항목별만족도_뷰티미용관광',
    'Q12a13': '항목별만족도_치료건강검진',
    'Q12a14': '항목별만족도_스포츠관람',
    'Q12a15': '항목별만족도_스포츠레포츠참가',
    'Q12a19': '항목별만족도_여행경비',
    'Q12a20': '항목별만족도_숙박시설',
    'Q13': '재방문의사',
    'Q14': '타인추천의향',
    'D_MON': '월별',
    'D_BUN': '분기별',
    'D_NAT': '국가별',
    'D_SEX': '성별',
    'D_AGE': '연령별',
    'D_MOK': '방한목적별',
    'D_NUM': '방한횟수별',
    'D_GUB': '여행형태별',
    'weight': 'weight',
    'year': 'year'
}

d23 = d23[list(new_names.keys())].rename(columns=new_names)
d23.head()
# Out:
#    id  방문횟수  여행형태  방한목적  고려한_관광활동_1  고려한_관광활동_2  고려한_관광활동_3  고려한_인프라_1  고려한_인프라_2  고려한_인프라_3  참여_식도락관광  참여_쇼핑  참여_자연경관감상  참여_역사유적지방문  참여_전통문화체험  참여_박물관전시관관람  참여_한류스타관련  참여_공연관람  참여_지역축제  참여_유흥  참여_오락  참여_뷰티미용관광  참여_치료건강검진  참여_스포츠관람  참여_스포츠레포츠참가  참여_국제회의  참여_비즈니스  참여_연수교육연구  참여_기타  만족한활동_1  만족한활동_2  만족한활동_3  방문지역_서울  방문지역_경기  방문지역_인천  방문지역_강원  방문지역_대전  방문지역_충북  방문지역_충남  방문지역_세종  방문지역_경북  방문지역_경남  방문지역_대구  방문지역_울산  방문지역_부산  방문지역_광주  방문지역_전북  방문지역_전남  방문지역_제주  총체재기간(코드형)  총체재기간   1인지출경비  1인1일지출경비  1인지출경비_영향치결측  1인지출경비_상하위1%대체  1인1일지출경비_영향치_61일이상결측  1인1일지출경비_상하위1%대체  1인1일지출경비_상하위1%대체_61일이상결측  형태별_1일지출경비  형태별_1일지출경비_상하위1%대체_61일이상결측  형태별_1일지출경비_항공제외대체결측  항목별지출경비_쇼핑  항목별지출경비_치료  항목별지출경비_미용  항목별지출경비_음식점  항목별지출경비_식음료  항목별지출경비숙박비  항목별지출경비_문화서비스  전반적만족도  항목별만족도_식도락  항목별만족도_쇼핑  항목별만족도_자연경관감상  항목별만족도_뷰티미용관광  항목별만족도_치료건강검진  항목별만족도_스포츠관람  항목별만족도_스포츠레포츠참가  항목별만족도_여행경비  항목별만족도_숙박시설  재방문의사  타인추천의향  월별  분기별  국가별  성별  연령별  방한목적별  방한횟수별  여행형태별      weight  year
# ...

# %%
#2024

cols_to_keep24 = [
        "pnid", "RVIT", "TYP", "Q1", "Q3_1a1", "Q3_1a2", "Q3_1a3", "Q3_2a1",
        "Q3_2a2", "Q3_2a3","Q8a01", "Q8a02",
        "Q8a03", "Q8a04", "Q8a05", "Q8a06","Q8a07", "Q8a08", "Q8a09", "Q8a10",
        "Q8a11", "Q8a12", "Q8a13","Q8a14", "Q8a15", "Q8a16", "Q8a17", "Q8a18",
        "Q8a19", "Q8a20","Q8_1a1","Q8_1a2","Q8_1a3","Q9_2a01", "Q9_2a02",
        "Q9_2a03", "Q9_2a04","Q9_2a05", "Q9_2a06", "Q9_2a07", "Q9_2a08",
        "Q9_2a09", "Q9_2a10","Q9_2a11", "Q9_2a12", "Q9_2a13", "Q9_2a14",
        "Q9_2a15", "Q9_2a16","Q9_2a17",
        "R일HAP",  "Q9_5A1", "Q9_5A2", "Q9_5A3", "Q9_5A4", "Q9_5A5",
        "Q9_5A6", "Q9_5A7", "Q9_5A8", "Q9_5A9","C총액1인TOT2",'M일HAP','총액1인TOT2','MDAY전체TOT_RAW61',
        "C총액1인TOT_개별국제교통비제외2","RDAY전체TOT_RAW61","RDAY전체_개별국제교통비제외61",
        "C음식점1인대체","C식음료1인대체","C숙박비1인대체","C쇼핑비1인대체","C치료및1인대체","C문화서1인대체",
        "C미용서1인대체", "Q11", "Q12a01",
        "Q12a02", "Q12a03", "Q12a05", "Q12a06", "Q12a07", "Q12a08",
        "Q12a09", "Q12a10", "Q12a11", "Q12a12", "Q12a13", "Q12a14", "Q12a15",
        "Q12a16", "Q12a17", "Q12a18", "Q12a19", "Q12a20", "Q13", "Q14",
        "D_MON", "D_BUN", "D_NAT", "D_SEX", "D_AGE", "D_MOK", "D_NUM",
        "D_GUB", "weight", "year"
    ]

# 필요한 컬럼만 선택
d24 = df24[cols_to_keep24]
d24.head()
# Out:
#    pnid  RVIT  TYP  Q1  Q3_1a1  Q3_1a2  Q3_1a3  Q3_2a1  Q3_2a2  Q3_2a3  Q8a01  Q8a02  Q8a03  Q8a04  Q8a05  Q8a06  Q8a07  Q8a08  Q8a09  Q8a10  Q8a11  Q8a12  Q8a13  Q8a14  Q8a15  Q8a16  Q8a17  Q8a18  Q8a19  Q8a20  Q8_1a1  Q8_1a2  Q8_1a3  Q9_2a01  Q9_2a02  Q9_2a03  Q9_2a04  Q9_2a05  Q9_2a06  Q9_2a07  Q9_2a08  Q9_2a09  Q9_2a10  Q9_2a11  Q9_2a12  Q9_2a13  Q9_2a14  Q9_2a15  Q9_2a16  Q9_2a17  R일HAP  Q9_5A1  Q9_5A2  Q9_5A3  Q9_5A4  Q9_5A5  Q9_5A6  Q9_5A7  Q9_5A8  Q9_5A9  C총액1인TOT2  M일HAP  총액1인TOT2  MDAY전체TOT_RAW61  C총액1인TOT_개별국제교통비제외2  RDAY전체TOT_RAW61  RDAY전체_개별국제교통비제외61  C음식점1인대체  C식음료1인대체  C숙박비1인대체  C쇼핑비1인대체  C치료및1인대체  C문화서1인대체  C미용서1인대체  Q11  Q12a01  Q12a02  Q12a03  Q12a05  Q12a06  Q12a07  Q12a08  Q12a09  Q12a10  Q12a11  Q12a12  Q12a13  Q12a14  Q12a15  Q12a16  Q12a17  Q12a18  Q12a19  Q12a20  Q13  Q14  D_MON  D_BUN  D_NAT  D_SEX  D_AGE  D_MOK  D_NUM  D_GUB   weight  year
# ...

# %%
# 컬럼명 매핑 딕셔너리
new_names = {
    'pnid': 'id',
    'RVIT': '방문횟수',
    'TYP': '여행형태',
    'Q1': '방한목적',
    'Q3_1a1': '고려한_관광활동_1',
    'Q3_1a2': '고려한_관광활동_2',
    'Q3_1a3': '고려한_관광활동_3',
    'Q3_2a1': '고려한_인프라_1',
    'Q3_2a2': '고려한_인프라_2',
    'Q3_2a3': '고려한_인프라_3',
    'Q8a01': '참여_식도락관광',
    'Q8a02': '참여_쇼핑',
    'Q8a03': '참여_자연경관감상',
    'Q8a04': '참여_휴양휴식웰니스',
    'Q8a05': '참여_역사유적지방문',
    'Q8a06': '참여_전통문화체험',
    'Q8a07': '참여_박물관전시관관람',
    'Q8a08': '참여_한류스타관련',
    'Q8a09': '참여_공연관람',
    'Q8a10': '참여_지역축제',
    'Q8a11': '참여_유흥',
    'Q8a12': '참여_오락',
    'Q8a13': '참여_뷰티미용관광',
    'Q8a14': '참여_치료건강검진',
    'Q8a15': '참여_스포츠관람',
    'Q8a16': '참여_스포츠레포츠참가',
    'Q8a17': '참여_국제회의',
    'Q8a18': '참여_비즈니스',
    'Q8a19': '참여_연수교육연구',
    'Q8a20': '참여_기타',
    'Q8_1a1': '만족한활동_1',
    'Q8_1a2': '만족한활동_2',
    'Q8_1a3': '만족한활동_3',
    'Q9_2a01': '방문지역_서울',
    'Q9_2a02': '방문지역_경기',
    'Q9_2a03': '방문지역_인천',
    'Q9_2a04': '방문지역_강원',
    'Q9_2a05': '방문지역_대전',
    'Q9_2a06': '방문지역_충북',
    'Q9_2a07': '방문지역_충남',
    'Q9_2a08': '방문지역_세종',
    'Q9_2a09': '방문지역_경북',
    'Q9_2a10': '방문지역_경남',
    'Q9_2a11': '방문지역_대구',
    'Q9_2a12': '방문지역_울산',
    'Q9_2a13': '방문지역_부산',
    'Q9_2a14': '방문지역_광주',
    'Q9_2a15': '방문지역_전북',
    'Q9_2a16': '방문지역_전남',
    'Q9_2a17': '방문지역_제주',
    'R일HAP': '총체재기간(코드형)',
    'M일HAP':'총체재기간',
    'Q9_5A1': '주요이용숙박시설_1',
    'Q9_5A2': '주요이용숙박시설_2',
    'Q9_5A3': '주요이용숙박시설_3',
    'Q9_5A4': '주요이용숙박시설_4',
    'Q9_5A5': '주요이용숙박시설_5',
    'Q9_5A6': '주요이용숙박시설_6',
    'Q9_5A7': '주요이용숙박시설_7',
    'Q9_5A8': '주요이용숙박시설_8',
    'Q9_5A9': '주요이용숙박시설_9',
    '총액1인TOT2': '1인지출경비',
    'MDAY전체TOT_RAW61': '1인1일지출경비',
    'C총액1인TOT2': '1인지출경비_상하위1%대체',
    'C총액1인TOT_개별국제교통비제외2': '1인_지출경비_국제교통비제외',
    'RDAY전체TOT_RAW61': '1인1일_지출경비_61일이상결측',
    'RDAY전체_개별국제교통비제외61': '1인1일_지출경비_국제교통비제외_61일이상결측',
    'C음식점1인대체': '항목별지출경비_음식점',
    'C식음료1인대체': '항목별지출경비_식음료',
    'C숙박비1인대체': '항목별지출경비숙박비',
    'C쇼핑비1인대체': '항목별지출경비_쇼핑',
    'C치료및1인대체': '항목별지출경비_치료',
    'C미용서1인대체': '항목별지출경비_미용',
    'C문화서1인대체':'항목별지출경비_문화서비스' ,
    'Q11': '전반적만족도',
    'Q12a01': '항목별만족도_식도락',
    'Q12a02': '항목별만족도_쇼핑',
    'Q12a03': '항목별만족도_자연경관감상',
    'Q12a05': '항목별만족도_trad_culture',
    'Q12a06': '항목별만족도_전시관람',
    'Q12a07': '항목별만족도_kpop_drama',
    'Q12a08': '항목별만족도_performance',
    'Q12a09': '항목별만족도_festival',
    'Q12a10': '항목별만족도_entertainment',
    'Q12a11': '항목별만족도_recreation',
    'Q12a12': '항목별만족도_뷰티미용관광',
    'Q12a13': '항목별만족도_치료건강검진',
    'Q12a14': '항목별만족도_스포츠관람',
    'Q12a15': '항목별만족도_스포츠레포츠참가',
    'Q12a16': '항목별만족도_immigration',
    'Q12a17': '항목별만족도_language',
    'Q12a18': '항목별만족도_safety',
    'Q12a19': '항목별만족도_여행경비',
    'Q12a20': '항목별만족도_숙박시설',
    'Q13': '재방문의사',
    'Q14': '타인추천의향',
    'D_MON': '월별',
    'D_BUN': '분기별',
    'D_NAT': '국가별',
    'D_SEX': '성별',
    'D_AGE': '연령별',
    'D_MOK': '방한목적별',
    'D_NUM': '방한횟수별',
    'D_GUB': '여행형태별',
    'weight': 'weight',
    'year': 'year'
}

# 컬럼 선택 및 이름 변경
d24 = d24[list(new_names.keys())].rename(columns=new_names)
d24.head()
# Out:
#    id  방문횟수  여행형태  방한목적  고려한_관광활동_1  고려한_관광활동_2  고려한_관광활동_3  고려한_인프라_1  고려한_인프라_2  고려한_인프라_3  참여_식도락관광  참여_쇼핑  참여_자연경관감상  참여_휴양휴식웰니스  참여_역사유적지방문  참여_전통문화체험  참여_박물관전시관관람  참여_한류스타관련  참여_공연관람  참여_지역축제  참여_유흥  참여_오락  참여_뷰티미용관광  참여_치료건강검진  참여_스포츠관람  참여_스포츠레포츠참가  참여_국제회의  참여_비즈니스  참여_연수교육연구  참여_기타  만족한활동_1  만족한활동_2  만족한활동_3  방문지역_서울  방문지역_경기  방문지역_인천  방문지역_강원  방문지역_대전  방문지역_충북  방문지역_충남  방문지역_세종  방문지역_경북  방문지역_경남  방문지역_대구  방문지역_울산  방문지역_부산  방문지역_광주  방문지역_전북  방문지역_전남  방문지역_제주  총체재기간(코드형)  총체재기간  주요이용숙박시설_1  주요이용숙박시설_2  주요이용숙박시설_3  주요이용숙박시설_4  주요이용숙박시설_5  주요이용숙박시설_6  주요이용숙박시설_7  주요이용숙박시설_8  주요이용숙박시설_9   1인지출경비  1인1일지출경비  1인지출경비_상하위1%대체  1인_지출경비_국제교통비제외  1인1일_지출경비_61일이상결측  1인1일_지출경비_국제교통비제외_61일이상결측  항목별지출경비_음식점  항목별지출경비_식음료  항목별지출경비숙박비  항목별지출경비_쇼핑  항목별지출경비_치료  항목별지출경비_미용  항목별지출경비_문화서비스  전반적만족도  항목별만족도_식도락  항목별만족도_쇼핑  항목별만족도_자연경관감상  항목별만족도_trad_culture  항목별만족도_전시관람  항목별만족도_kpop_drama  항목별만족도_performance  항목별만족도_festival  항목별만족도_entertainment  항목별만족도_recreation  항목별만족도_뷰티미용관광  항목별만족도_치료건강검진  \
# ...

# %%
# 데이터 합치기
data = pd.concat([d23, d24], ignore_index=True)
data.tail()
data.info() # 32411 rows × 103 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32412 entries, 0 to 32411
# Columns: 113 entries, id to 항목별만족도_safety
# dtypes: float64(85), int64(28)
# memory usage: 27.9 MB

# %%
data.to_csv('/content/drive/MyDrive/데이터톤/데이터/2324전처리.csv', index=False, encoding='utf-8-sig')
